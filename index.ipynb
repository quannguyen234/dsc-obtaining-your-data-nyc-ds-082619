# %% [markdown]
# # Obtaining Your Data
#
# ## Introduction
# In this lesson, you'll synthesize many of your data loading skills you learned to date in order to merge multiple datasets from various sources.
#
# ## Objectives
# You will be able to:
# * Understand the ETL process and the steps it consists of
# * Understand the challenges of working with data from multiple sources
#
# ## Loading SQL DB to DataFrames
# <img src="Database-Schema.png">

# %%
import sqlite3
import pandas as pd

# Create a connection
con = sqlite3.connect('data.sqlite')
# Create a cursor
cur = con.cursor()
# Select some data
cur.execute("""SELECT * FROM orders JOIN orderdetails USING(orderNumber);""")
df = pd.DataFrame(cur.fetchall())
df.columns = [i[0] for i in cur.description]
print(df.shape)
df.head()
# Out:
# (2996, 11)
#   orderNumber   orderDate requiredDate shippedDate   status  \
# 0       10100  2003-01-06   2003-01-13  2003-01-10  Shipped
# 1       10100  2003-01-06   2003-01-13  2003-01-10  Shipped
# 2       10100  2003-01-06   2003-01-13  2003-01-10  Shipped
# 3       10100  2003-01-06   2003-01-13  2003-01-10  Shipped
# 4       10101  2003-01-09   2003-01-18  2003-01-11  Shipped
#
#                  comments customerNumber productCode quantityOrdered  \
# 0                                    363    S18_1749              30
# 1                                    363    S18_2248              50
# 2                                    363    S18_4409              22
# 3                                    363    S24_3969              49
# 4  Check on availability.            128    S18_2325              25
#
#   priceEach orderLineNumber
# 0    136.00               3
# 1     55.09               2
# 2     75.46               4
# 3     35.29               1
# 4    108.06               4

# %%
# Create a connection
con = sqlite3.connect('data.sqlite')
# Create a cursor
cur = con.cursor()
# Select some data
cur.execute("""SELECT * FROM products;""")
df = pd.DataFrame(cur.fetchall())
df.columns = [i[0] for i in cur.description]
print(df.shape)
df.head()
# Out:
# (110, 9)
#   productCode                            productName   productLine  \
# 0    S10_1678  1969 Harley Davidson Ultimate Chopper   Motorcycles
# 1    S10_1949               1952 Alpine Renault 1300  Classic Cars
# 2    S10_2016                  1996 Moto Guzzi 1100i   Motorcycles
# 3    S10_4698   2003 Harley-Davidson Eagle Drag Bike   Motorcycles
# 4    S10_4757                    1972 Alfa Romeo GTA  Classic Cars
#
#   productScale             productVendor  \
# 0         1:10           Min Lin Diecast
# 1         1:10   Classic Metal Creations
# 2         1:10  Highway 66 Mini Classics
# 3         1:10         Red Start Diecast
# 4         1:10   Motor City Art Classics
#
#                                   productDescription quantityInStock buyPrice  \
# 0  This replica features working kickstand, front...            7933    48.81
# 1  Turnable front wheels; steering function; deta...            7305    98.58
# 2  Official Moto Guzzi logos and insignias, saddl...            6625    68.99
# 3  Model features, official Harley Davidson logos...            5582    91.02
# 4  Features include: Turnable front wheels; steer...            3252    85.68
#
#      MSRP
# 0   95.70
# 1  214.30
# 2  118.94
# 3  193.66
# 4  136.00

# %% [markdown]
# ## Merging Data
#
# Recall that you can also join data from multiple tables in SQL.

# %%
# Create a connection
con = sqlite3.connect('data.sqlite')
# Create a cursor
cur = con.cursor()
# Select some data
cur.execute("""SELECT * FROM products
                        JOIN orderdetails
                        USING (productCode);""")
df = pd.DataFrame(cur.fetchall())
df.columns = [i[0] for i in cur.description]
print(df.shape)
df.head()
# Out:
# (2996, 13)
#   productCode                            productName  productLine  \
# 0    S10_1678  1969 Harley Davidson Ultimate Chopper  Motorcycles
# 1    S10_1678  1969 Harley Davidson Ultimate Chopper  Motorcycles
# 2    S10_1678  1969 Harley Davidson Ultimate Chopper  Motorcycles
# 3    S10_1678  1969 Harley Davidson Ultimate Chopper  Motorcycles
# 4    S10_1678  1969 Harley Davidson Ultimate Chopper  Motorcycles
#
#   productScale    productVendor  \
# 0         1:10  Min Lin Diecast
# 1         1:10  Min Lin Diecast
# 2         1:10  Min Lin Diecast
# 3         1:10  Min Lin Diecast
# 4         1:10  Min Lin Diecast
#
#                                   productDescription quantityInStock buyPrice  \
# 0  This replica features working kickstand, front...            7933    48.81
# 1  This replica features working kickstand, front...            7933    48.81
# 2  This replica features working kickstand, front...            7933    48.81
# 3  This replica features working kickstand, front...            7933    48.81
# 4  This replica features working kickstand, front...            7933    48.81
#
#     MSRP orderNumber quantityOrdered priceEach orderLineNumber
# 0  95.70       10107              30     81.35               2
# 1  95.70       10121              34     86.13               5
# 2  95.70       10134              41     90.92               2
# 3  95.70       10145              45     76.56               6
# 4  95.70       10159              49     81.35              14

# %% [markdown]
# You can also merge data from a separate csv file. For example, say you take a separate data source regarding daily sales data for the various branches. You might first generate a view from our database:

# %%
# Create a connection
con = sqlite3.connect('data.sqlite')
# Create a cursor
cur = con.cursor()
# Select some data
cur.execute("""SELECT * FROM customers
                        JOIN orders
                        USING(customerNumber);""")
df = pd.DataFrame(cur.fetchall())
df.columns = [i[0] for i in cur.description]
print(df.shape)
df.head()
# Out:
# (326, 19)
#   customerNumber        customerName contactLastName contactFirstName  \
# 0            103   Atelier graphique         Schmitt          Carine
# 1            103   Atelier graphique         Schmitt          Carine
# 2            103   Atelier graphique         Schmitt          Carine
# 3            112  Signal Gift Stores            King             Jean
# 4            112  Signal Gift Stores            King             Jean
#
#         phone     addressLine1 addressLine2       city state postalCode  \
# 0  40.32.2555   54, rue Royale                  Nantes            44000
# 1  40.32.2555   54, rue Royale                  Nantes            44000
# 2  40.32.2555   54, rue Royale                  Nantes            44000
# 3  7025551838  8489 Strong St.               Las Vegas    NV      83030
# 4  7025551838  8489 Strong St.               Las Vegas    NV      83030
#
#   country salesRepEmployeeNumber creditLimit orderNumber   orderDate  \
# 0  France                   1370    21000.00       10123  2003-05-20
# 1  France                   1370    21000.00       10298  2004-09-27
# 2  France                   1370    21000.00       10345  2004-11-25
# 3     USA                   1166    71800.00       10124  2003-05-21
# 4     USA                   1166    71800.00       10278  2004-08-06
#
#   requiredDate shippedDate   status  \
# 0   2003-05-29  2003-05-22  Shipped
# 1   2004-10-05  2004-10-01  Shipped
# 2   2004-12-01  2004-11-26  Shipped
# 3   2003-05-29  2003-05-25  Shipped
# 4   2004-08-16  2004-08-09  Shipped
#
#                                             comments
# 0
# 1
# 2
# 3  Customer very concerned about the exact color ...
# 4

# %% [markdown]
# And then load the seperate datefile:

# %%
daily_sums = pd.read_csv('Daily_Sales_Summaries.csv')
daily_sums.head()
# Out:
#     orderDate      min      max       sum         mean          std
# 0  2003-01-06  1660.12  4080.00  10223.83  2555.957500  1132.572429
# 1  2003-01-09  1463.85  4343.56  10549.01  2637.252500  1244.866467
# 2  2003-01-10  1768.33  3726.45   5494.78  2747.390000  1384.599930
# 3  2003-01-29  1283.48  5571.80  50218.95  3138.684375  1168.280303
# 4  2003-01-31  1338.04  4566.99  40206.20  3092.784615  1148.570425

# %%
merged = pd.merge(df, daily_sums)
merged
# Out:
#     customerNumber                    customerName contactLastName  \
# 0              103               Atelier graphique         Schmitt
# 1              103               Atelier graphique         Schmitt
# 2              103               Atelier graphique         Schmitt
# 3              350            Marseille Mini Autos         Lebihan
# 4              112              Signal Gift Stores            King
# 5              114      Australian Collectors, Co.        Ferguson
# 6              112              Signal Gift Stores            King
# 7              112              Signal Gift Stores            King
# 8              114      Australian Collectors, Co.        Ferguson
# 9              114      Australian Collectors, Co.        Ferguson
# 10             114      Australian Collectors, Co.        Ferguson
# 11             114      Australian Collectors, Co.        Ferguson
# 12             216              Enaco Distributors        Saavedra
# 13             353              Reims Collectables         Henriot
# 14             382           Salzburg Collectables           Pipps
# 15             119               La Rochelle Gifts         Labrune
# 16             119               La Rochelle Gifts         Labrune
# 19            Diego      (91) 555 94 44            C/ Moralzarzal, 86
# 20            Jonas          07-98 9555        Erling Skakkes gate 78
# 21            Jonas          07-98 9555        Erling Skakkes gate 78
# 22             Julie         6505551386               7734 Strong St.
# 23            Jonas          07-98 9555        Erling Skakkes gate 78
# 24             Steve         9145554562     3758 North Pendale Street
# 25            Jonas          07-98 9555        Erling Skakkes gate 78
# 26            Roland  +49 69 66 90 2555                 Lyonerstr. 34
# 27           Michael         2125551500             2678 Kingston Rd.
# 28             Susan         4155551450               5677 Strong St.
# 29             Susan         4155551450               5677 Strong St.
# ..               ...                ...                           ...
# 296           Martha       0695-34 6555                  Åkergatan 24
# 297           Martha       0695-34 6555                  Åkergatan 24
# 298          Violeta         5085552555             1785 First Street
# 299              Sue         4085553659                3086 Ingle Ln.
# 300              Sue         4085553659                3086 Ingle Ln.
# 301              Sue         4085553659                3086 Ingle Ln.
# 302             Tony      +64 9 5555500            Arenales 1938 3'A'
# 303          Roland           7675-3555                  Kirchgasse 6
# 304          Violeta         5085552555             1785 First Street
# 305          Roland           7675-3555                  Kirchgasse 6
# 306           Leslie         2035559545      567 North Pendale Street
# 307               Yu         2125551957     5290 North Pendale Street
# 308          Martín      (91) 555 22 82                C/ Araquil, 67
# 309          Martín      (91) 555 22 82                C/ Araquil, 67
# 310             Sean     61-9-3844-6555                7 Allen Street
# 311             Sean     61-9-3844-6555                7 Allen Street
# 312             Sean     61-9-3844-6555                7 Allen Street
# 313           Franco      +39 022515555         20093 Cologno Monzese
# 314           Franco      +39 022515555         20093 Cologno Monzese
# 315            Steve         3105553722             3675 Furth Circle
# 316      José Pedro      (95) 555 82 82                 C/ Romero, 33
# 317             Rosa         2155559857             11328 Douglas Av.
# 318             Rosa         2155559857             11328 Douglas Av.
# 319              Sue         4155554312             2793 Furth Circle
# 320              Sue         4155554312             2793 Furth Circle
# 321          Thomas      (171) 555-7555               120 Hanover Sq.
# 322          Valarie         6175552555                6251 Ingle Ln.
# 323          Valarie         6175552555                6251 Ingle Ln.
# 324             Tony      +64 9 5555500            Arenales 1938 3'A'
# 325             Tony      +64 9 5555500            Arenales 1938 3'A'
#
#             addressLine2           city     state postalCode     ...       \
# 0                                Nantes                44000     ...
# 1                                Nantes                44000     ...
# 2                                Nantes                44000     ...
# 3                             Marseille                13008     ...
# 4                             Las Vegas        NV      83030     ...
# 5                Level 3      Melbourne  Victoria       3004     ...
# 6                             Las Vegas        NV      83030     ...
# 7                             Las Vegas        NV      83030     ...
# 8                Level 3      Melbourne  Victoria       3004     ...
# 9                Level 3      Melbourne  Victoria       3004     ...
# 10               Level 3      Melbourne  Victoria       3004     ...
# 11               Level 3      Melbourne  Victoria       3004     ...
# 12                            Barcelona                08022     ...
# 13                                Reims                51100     ...
# 14                             Salzburg                 5020     ...
# 15                               Nantes                44000     ...
# 16                               Nantes                44000     ...
# 17                               Nantes                44000     ...
# 18                               Nantes                44000     ...
# 19                               Madrid                28034     ...
# 20                              Stavern                 4110     ...
# 21                              Stavern                 4110     ...
# 22                        San Francisco        CA      94217     ...
# 23                              Stavern                 4110     ...
# 24                         White Plains        NY      24067     ...
# 25                              Stavern                 4110     ...
# 26                            Frankfurt                60528     ...
# 27             Suite 101            NYC        NY      10022     ...
# 28                           San Rafael        CA      97562     ...
# 29                           San Rafael        CA      97562     ...
# ..                   ...            ...       ...        ...     ...
# 296                              Bräcke             S-844 67     ...
# 297                              Bräcke             S-844 67     ...
# 298                         New Bedford        MA      50553     ...
# 299                            San Jose        CA      94217     ...
# 300                            San Jose        CA      94217     ...
# 301                            San Jose        CA      94217     ...
# 302                          Auckland                            ...
# 303                                Graz                 8010     ...
# 304                         New Bedford        MA      50553     ...
# 305                                Graz                 8010     ...
# 306                           New Haven        CT      97823     ...
# 307            Suite 200            NYC        NY      10022     ...
# 308                              Madrid                28023     ...
# 309                              Madrid                28023     ...
# 310                        Glen Waverly  Victoria       3150     ...
# 311                        Glen Waverly  Victoria       3150     ...
# 312                        Glen Waverly  Victoria       3150     ...
# 313  Alessandro Volta 16          Milan                          ...
# 314  Alessandro Volta 16          Milan                          ...
# 315                             Burbank        CA      94019     ...
# 316                             Sevilla                41101     ...
# 317                        Philadelphia        PA      71270     ...
# 318                        Philadelphia        PA      71270     ...
# 319                            Brisbane        CA      94217     ...
# 320                            Brisbane        CA      94217     ...
# 321                              London              WA1 1DP     ...
# 322                              Boston        MA      51003     ...
# 323                              Boston        MA      51003     ...
# 324                          Auckland                            ...
# 325                          Auckland                            ...
#
#       orderDate requiredDate shippedDate      status  \
# 0    2003-05-20   2003-05-29  2003-05-22     Shipped
# 1    2004-09-27   2004-10-05  2004-10-01     Shipped
# 2    2004-11-25   2004-12-01  2004-11-26     Shipped
# 3    2004-11-25   2004-12-02  2004-11-29     Shipped
# 4    2003-05-21   2003-05-29  2003-05-25     Shipped
# 5    2003-05-21   2003-05-27  2003-05-24     Shipped
# 6    2004-08-06   2004-08-16  2004-08-09     Shipped
# 7    2004-11-29   2004-12-05  2004-11-30     Shipped
# 8    2004-11-29   2004-12-07  2004-11-30     Shipped
# 9    2003-04-29   2003-05-08  2003-05-01     Shipped
# 10   2004-02-20   2004-02-29  2004-02-24     Shipped
# 11   2004-11-24   2004-12-01  2004-11-29     Shipped
# 12   2004-11-24   2004-12-01  2004-11-25     Shipped
# 13   2004-11-24   2004-12-01  2004-11-26     Shipped
# 14   2004-11-24   2004-12-01  2004-11-29     Shipped
# 15   2004-07-23   2004-08-02  2004-07-29     Shipped
# 16   2004-10-29   2004-11-08  2004-10-30     Shipped
# 17   2005-02-03   2005-02-10  2005-02-06     Shipped
# 18   2005-05-31   2005-06-07              In Process
# 19   2005-05-31   2005-06-08              In Process
# 20   2003-01-29   2003-02-07  2003-02-02     Shipped
# 21   2003-10-10   2003-10-18  2003-10-15     Shipped
# 22   2003-10-10   2003-10-19  2003-10-16     Shipped
# 23   2004-10-15   2004-10-24  2004-10-18     Shipped
# 24   2004-10-15   2004-10-24  2004-10-20     Shipped
# 25   2004-11-05   2004-11-13  2004-11-08     Shipped
# 26   2004-11-05   2004-11-12  2004-11-09     Shipped
# 27   2004-11-05   2004-11-11  2004-11-08     Shipped
# 310   35505.63  2219.101875  1077.631810
# 311    9415.13  4707.565000  1898.532210
# 312   10945.26  2189.052000  1345.117759
# 313   17746.26  2957.710000  1307.090649
# 314    7612.06  3806.030000  1945.830583
# 315   36070.47  3607.047000  1719.545410
# 316    3474.66  1737.330000  1245.257468
# 317   25833.14  4305.523333  2323.952541
# 318    5899.38  1966.460000   653.460738
# 319   29997.09  2727.008182  1568.196273
# 320   12573.28  3143.320000  2374.138863
# 321    7310.42  2436.806667   894.344201
# 322   59265.14  3704.071250  1564.227089
# 323    6276.60  3138.300000  2997.552925
# 324   32077.44  2467.495385  1382.146181
# 325   52166.00  2898.111111  1050.057830
#
# [326 rows x 24 columns]

# %% [markdown]
# ## Checking Merged Data
#
# It's always good practice to check assumptions and preview transformed data views throughout your process. Let's take a look:

# %%
merged.head()
# Out:
#   customerNumber          customerName contactLastName contactFirstName  \
# 0            103     Atelier graphique         Schmitt          Carine
# 1            103     Atelier graphique         Schmitt          Carine
# 2            103     Atelier graphique         Schmitt          Carine
# 3            350  Marseille Mini Autos         Lebihan        Laurence
# 4            112    Signal Gift Stores            King             Jean
#
#         phone          addressLine1 addressLine2       city state postalCode  \
# 0  40.32.2555        54, rue Royale                  Nantes            44000
# 1  40.32.2555        54, rue Royale                  Nantes            44000
# 2  40.32.2555        54, rue Royale                  Nantes            44000
# 3  91.24.4555  12, rue des Bouchers               Marseille            13008
# 4  7025551838       8489 Strong St.               Las Vegas    NV      83030
#
#    ...   orderDate requiredDate shippedDate   status  \
# 0  ...  2003-05-20   2003-05-29  2003-05-22  Shipped
# 1  ...  2004-09-27   2004-10-05  2004-10-01  Shipped
# 2  ...  2004-11-25   2004-12-01  2004-11-26  Shipped
# 3  ...  2004-11-25   2004-12-02  2004-11-29  Shipped
# 4  ...  2003-05-21   2003-05-29  2003-05-25  Shipped
#
#                                             comments      min      max  \
# 0                                                     2163.50  5282.64
# 1                                                     1938.24  4128.54
# 2                                                      557.60  7573.50
# 3                                                      557.60  7573.50
# 4  Customer very concerned about the exact color ...   798.38  4704.92
#
#         sum         mean          std
# 0  14571.44  3642.860000  1322.891537
# 1   6066.78  3033.390000  1548.775983
# 2  20564.45  2570.556250  2178.832190
# 3  20564.45  2570.556250  2178.832190
# 4  40207.06  2680.470667  1255.052262
#
# [5 rows x 24 columns]

# %% [markdown]
# Pandas' `merge()` function conveniently uses common column names between the DataFrames as keys. You can always specifically specify what columns to join on by using the `on` keyword as in `pd.merge(df1, df2, on=[col1, col2])`. Unfortunately, columns that are not identically named beforehand will not work with this convenience method. Additionally, it is imperative to check the formatting of the join keys between the tables. A number formatted as a string can often ruin joins, and separate formatting conventions such as 'U.S.' versus 'USA' are also important preprocessing considerations before merging data files from various sources. In this case, everything worked smoothly, but it's good to keep in mind what problems may occur.
#
# ## Saving Transformed Data to File
# Finally, we can save our transformed dataset.

# %%
merged.to_csv('Merged_Dataset.csv', index=False)

# %% [markdown]
# ## Summary
# Well done! In this lesson you reviewed merges, as well as potential pitfalls in merging datasets from different sources. In the next lab, you'll get some practice doing this as an initial step to a regression task.
